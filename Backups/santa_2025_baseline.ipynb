# %%
# Load and evaluate the existing test.csv to verify the score
try:
    test_df = pd.read_csv('test.csv')
    print("Loaded test.csv")
    
    # Parse the 's' prefix
    def parse_s(val):
        return float(val.replace('s', ''))
    
    test_df['x'] = test_df['x'].apply(parse_s)
    test_df['y'] = test_df['y'].apply(parse_s)
    test_df['deg'] = test_df['deg'].apply(parse_s)
    
    # Reconstruct trees and calculate score
    total_test_score = 0
    for n in range(1, 201):
        # Get rows for this N
        # The ID format is N_i, e.g., 001_0
        # We need to filter by the prefix
        prefix = f"{n:03d}_"
        rows = test_df[test_df['id'].str.startswith(prefix)]
        
        if len(rows) != n:
            print(f"Warning: N={n} has {len(rows)} rows, expected {n}")
            continue
            
        trees = []
        for _, row in rows.iterrows():
            trees.append(ChristmasTree(row['x'], row['y'], row['deg']))
            
        side = get_bounds(trees)
        score_n = (side ** 2) / n
        total_test_score += score_n
        
    print(f"Score of test.csv: {total_test_score:.4f}")
    
except Exception as e:
    print(f"Could not evaluate test.csv: {e}")
# Out:
# Loaded test.csv
# Score of test.csv: 74.7550
# Score of test.csv: 74.7550

# %%
## 2. Setup

import math
import random
import time
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from decimal import Decimal, getcontext
from shapely import affinity
from shapely.geometry import Polygon
from shapely.ops import unary_union
from shapely.strtree import STRtree
from tqdm.notebook import tqdm

# Set random seed
SEED = 2025
random.seed(SEED)
np.random.seed(SEED)

# High precision for coordinates
getcontext().prec = 50

print("Libraries imported and seed set.")
# Out:
# Libraries imported and seed set.

# %%
## 3. Load Data

# Load the sample submission to understand the required output format
try:
    sample_sub = pd.read_csv('test.csv')
    print("Sample Submission Shape:", sample_sub.shape)
    print(sample_sub.head())
except FileNotFoundError:
    print("Sample submission not found, proceeding without it.")
# Out:
# Sample Submission Shape: (20100, 4)
#       id               x               y               deg
# 0  001_0   s0.1590990258  s-0.1590990258    s45.0000000000
# 1  002_0  s-0.1540850432  s-0.2614654977    s23.6308512870
# 2  002_1   s0.1540988268   s0.2614652823  s-156.3702262410
# 3  003_0  s-0.2346200324   s0.1548200545   s155.1341740000
# 4  003_1   s0.3577229676   s0.2503590545    s66.3704810000

# %% [markdown]
# ## 4. Baseline Strategy
#
# We define the `GreedyPacker` class here. It encapsulates the logic for placing a single tree into an existing configuration.

# %%
class GreedyPacker:
    def __init__(self, n_trials=100, step_size=0.2, fine_step=0.02):
        self.n_trials = n_trials
        self.step_size = step_size
        self.fine_step = fine_step

    def _generate_weighted_angle(self):
        """
        Generates a random angle with a distribution weighted by abs(sin(2*angle)).
        This helps place more trees in corners (diagonals).
        """
        while True:
            angle = random.uniform(0, 2 * math.pi)
            if random.uniform(0, 1) < abs(math.sin(2 * angle)):
                return angle

    def place_next_tree(self, existing_trees, tree_class):
        """Finds the best position for the next tree given existing trees."""
        if not existing_trees:
            return tree_class(0, 0, 0)

        existing_polys = [t.polygon for t in existing_trees]
        tree_index = STRtree(existing_polys)
        
        # Calculate current bounds and center
        minx, miny, maxx, maxy = unary_union(existing_polys).bounds
        center_x = (minx + maxx) / 2
        center_y = (miny + maxy) / 2
        
        best_tree = None
        min_metric = float('inf')

        for _ in range(self.n_trials):
            # Random angle for the tree itself
            angle = random.uniform(0, 360)
            
            # Weighted approach angle (bias towards diagonals)
            approach_angle = self._generate_weighted_angle()
            vx, vy = math.cos(approach_angle), math.sin(approach_angle)
            
            # Start far away
            radius = max(maxx - minx, maxy - miny) + 10.0
            candidate = tree_class(0, 0, angle)
            
            # Move in
            current_r = radius
            collision = False
            
            # Coarse search
            while current_r > 0:
                px, py = center_x + current_r * vx, center_y + current_r * vy
                candidate.update_position(px, py, angle)
                
                query_indices = tree_index.query(candidate.polygon)
                if any(candidate.polygon.intersects(existing_polys[i]) for i in query_indices):
                    collision = True
                    break
                current_r -= self.step_size
            
            # Fine tune
            if collision:
                current_r += self.step_size
                while True:
                    current_r -= self.fine_step
                    px, py = center_x + current_r * vx, center_y + current_r * vy
                    candidate.update_position(px, py, angle)
                    
                    query_indices = tree_index.query(candidate.polygon)
                    if any(candidate.polygon.intersects(existing_polys[i]) for i in query_indices):
                        # Collision found, step back once and stop
                        current_r += self.fine_step
                        px, py = center_x + current_r * vx, center_y + current_r * vy
                        candidate.update_position(px, py, angle)
                        break
            else:
                candidate.update_position(center_x, center_y, angle)

            # Metric: Minimize the side length of the new bounding box
            t_minx, t_miny, t_maxx, t_maxy = candidate.polygon.bounds
            new_minx = min(minx, t_minx)
            new_miny = min(miny, t_miny)
            new_maxx = max(maxx, t_maxx)
            new_maxy = max(maxy, t_maxy)
            
            new_side = max(new_maxx - new_minx, new_maxy - new_miny)
            
            # Tie-breaker: distance to center
            dist_sq = (px - center_x)**2 + (py - center_y)**2
            
            metric = new_side + (dist_sq * 1e-6)
            
            if metric < min_metric:
                min_metric = metric
                best_tree = tree_class(px, py, angle)
                
        return best_tree

# %% [markdown]
# ## 5. Feature Engineering Module
#
# Here we define the geometric features of the problem: the `ChristmasTree` class and helper functions for bounding boxes.

# %%
class ChristmasTree:
    """Represents a single, rotatable Christmas tree."""
    def __init__(self, center_x=0, center_y=0, angle=0):
        self.center_x = float(center_x)
        self.center_y = float(center_y)
        self.angle = float(angle)
        self.polygon = self._create_polygon()

    def _create_polygon(self):
        # Tree dimensions
        coords = [
            (0.0, 0.8), (0.125, 0.5), (0.0625, 0.5), (0.2, 0.25), (0.1, 0.25),
            (0.35, 0.0), (0.075, 0.0), (0.075, -0.2), (-0.075, -0.2), (-0.075, 0.0),
            (-0.35, 0.0), (-0.1, 0.25), (-0.2, 0.25), (-0.0625, 0.5), (-0.125, 0.5)
        ]
        poly = Polygon(coords)
        rotated = affinity.rotate(poly, self.angle, origin=(0, 0))
        return affinity.translate(rotated, xoff=self.center_x, yoff=self.center_y)

    def update_position(self, x, y, angle):
        self.center_x = x
        self.center_y = y
        self.angle = angle
        self.polygon = self._create_polygon()

def get_bounds(trees):
    if not trees: return 0
    minx, miny, maxx, maxy = unary_union([t.polygon for t in trees]).bounds
    return max(maxx - minx, maxy - miny)

# %% [markdown]
# ## 6. Model Training (Optional)
#
# For this geometric packing problem, standard supervised learning is less applicable than search algorithms. However, one could train a model to predict the optimal *order* of placement or the optimal *angle* given the current boundary shape. We skip this for the baseline.

# %%
# Placeholder for ML model training
# model = LGBMRegressor(...)
# model.fit(X_train, y_train)

# %% [markdown]
# ## 7. Optimization Strategy
#
# We define a modular optimization function. Currently, it's a placeholder for a more advanced local search (e.g., trying to wiggle trees after placement).

# %%
def center_packing(trees):
    """Centers the packing at (0,0) based on the bounding box center."""
    if not trees: return trees
    minx, miny, maxx, maxy = unary_union([t.polygon for t in trees]).bounds
    cx = (minx + maxx) / 2
    cy = (miny + maxy) / 2
    
    # If already centered (small epsilon), skip
    if abs(cx) < 1e-9 and abs(cy) < 1e-9:
        return trees
        
    for t in trees:
        t.update_position(t.center_x - cx, t.center_y - cy, t.angle)
    return trees

def optimize_packing(trees, params, target_side=None):
    """
    Simulated Annealing with Rotation and Translation.
    Tries to perturb trees to minimize the bounding box side length.
    Includes Optuna-style pruning if target_side is provided.
    """
    if not trees: return trees
    
    # Ensure we start centered
    trees = center_packing(trees)
    
    iterations = params.get('iterations', 1000)
    
    # SA parameters
    initial_temp = params.get('initial_temp', 0.1)
    final_temp = params.get('final_temp', 1e-6)
    alpha = (final_temp / initial_temp) ** (1 / iterations) if iterations > 0 else 0.99
    
    # Step sizes
    max_step_size = params.get('step_size', 0.5)
    max_angle_step = params.get('angle_step', 10.0)
    compression = params.get('compression', 0.02)
    
    # Pre-calculate bounds of all trees
    polys = [t.polygon for t in trees]
    minxs = [p.bounds[0] for p in polys]
    minys = [p.bounds[1] for p in polys]
    maxxs = [p.bounds[2] for p in polys]
    maxys = [p.bounds[3] for p in polys]
    
    current_minx, current_miny = min(minxs), min(minys)
    current_maxx, current_maxy = max(maxxs), max(maxys)
    current_side = max(current_maxx - current_minx, current_maxy - current_miny)
    
    current_temp = initial_temp
    
    # Keep track of best solution found
    best_side = current_side
    best_state = [(t.center_x, t.center_y, t.angle) for t in trees]

    for i in range(iterations):
        # Pruning Check (Optuna-style)
        # If we are performing significantly worse than the target after some progress, abort.
        if target_side is not None and i > 100 and i % 50 == 0:
            progress = i / iterations
            # Relaxed pruning for high-temp starts (allow more chaos early on)
            # If we are >60% done and >15% worse than target, prune
            if progress > 0.6 and best_side > target_side * 1.15:
                # Restore best state found so far and return
                for k, t in enumerate(trees):
                    t.update_position(*best_state[k])
                return center_packing(trees)
            # If we are >90% done and >5% worse than target, prune
            if progress > 0.9 and best_side > target_side * 1.05:
                for k, t in enumerate(trees):
                    t.update_position(*best_state[k])
                return center_packing(trees)

        # Dynamic step size
        progress = i / iterations
        step_size = max_step_size * (1 - 0.9 * progress) # Decay to 10%
        angle_step = max_angle_step * (1 - 0.9 * progress)
        
        idx = random.randint(0, len(trees) - 1)
        tree = trees[idx]
        
        orig_x, orig_y, orig_angle = tree.center_x, tree.center_y, tree.angle
        orig_bounds = (minxs[idx], minys[idx], maxxs[idx], maxys[idx])
        
        # Center of current bounding box
        center_x = (current_minx + current_maxx) / 2
        center_y = (current_miny + current_maxy) / 2

        # Propose move
        if random.random() < 0.7: # Translation
            dx = (random.random() - 0.5) * step_size
            dy = (random.random() - 0.5) * step_size
            # Bias to center (Gravity)
            dx += (center_x - tree.center_x) * compression
            dy += (center_y - tree.center_y) * compression
            
            new_x, new_y, new_angle = tree.center_x + dx, tree.center_y + dy, tree.angle
        else: # Rotation
            new_x, new_y = tree.center_x, tree.center_y
            new_angle = tree.angle + (random.random() - 0.5) * angle_step
            
        tree.update_position(new_x, new_y, new_angle)
        
        # Check collision
        collision = False
        t_bounds = tree.polygon.bounds
        
        for j, other in enumerate(trees):
            if idx == j: continue
            # Fast bound check
            o_bounds = (minxs[j], minys[j], maxxs[j], maxys[j])
            if (t_bounds[0] > o_bounds[2] or t_bounds[2] < o_bounds[0] or 
                t_bounds[1] > o_bounds[3] or t_bounds[3] < o_bounds[1]):
                continue
                
            if tree.polygon.intersects(other.polygon):
                collision = True
                break
        
        if collision:
            tree.update_position(orig_x, orig_y, orig_angle)
            continue
            
        # Check metric
        minxs[idx], minys[idx], maxxs[idx], maxys[idx] = t_bounds
        
        new_global_minx, new_global_miny = min(minxs), min(minys)
        new_global_maxx, new_global_maxy = max(maxxs), max(maxys)
        new_side = max(new_global_maxx - new_global_minx, new_global_maxy - new_global_miny)
        
        delta = new_side - current_side
        
        accept = False
        if delta < 0:
            accept = True
        else:
            # Metropolis criterion
            if random.random() < math.exp(-delta / current_temp):
                accept = True
                
        if accept:
            current_side = new_side
            current_minx, current_miny, current_maxx, current_maxy = new_global_minx, new_global_miny, new_global_maxx, new_global_maxy
            
            if current_side < best_side:
                best_side = current_side
                best_state = [(t.center_x, t.center_y, t.angle) for t in trees]
        else:
            # Revert
            tree.update_position(orig_x, orig_y, orig_angle)
            minxs[idx], minys[idx], maxxs[idx], maxys[idx] = orig_bounds
            
        current_temp *= alpha
        
    # Restore best state
    for i, t in enumerate(trees):
        t.update_position(*best_state[i])
    
    # Final centering
    trees = center_packing(trees)
            
    return trees

# %% [markdown]
# ## 8. Submission Generation
#
# This section runs the full pipeline and generates the submission file.

# %%
from joblib import Parallel, delayed
import multiprocessing
from IPython.display import clear_output, display
import matplotlib.pyplot as plt
import os
import datetime

# Load baseline from test.csv
known_solutions = {}
try:
    print("Loading baseline from test.csv...")
    baseline_df = pd.read_csv('test.csv')
    
    def parse_s(val):
        return float(str(val).replace('s', ''))
    
    baseline_df['x'] = baseline_df['x'].apply(parse_s)
    baseline_df['y'] = baseline_df['y'].apply(parse_s)
    baseline_df['deg'] = baseline_df['deg'].apply(parse_s)
    
    for n in range(1, 201):
        prefix = f"{n:03d}_"
        rows = baseline_df[baseline_df['id'].str.startswith(prefix)]
        if len(rows) == n:
            trees = []
            for _, row in rows.iterrows():
                trees.append(ChristmasTree(row['x'], row['y'], row['deg']))
            known_solutions[n] = trees
            
    print(f"Loaded {len(known_solutions)} configurations from test.csv")
    
except Exception as e:
    print(f"Could not load baseline: {e}")

# Helper function for parallel execution (REVERSE MODE)
def process_beam_candidate_reverse(base_trees, n, packer_params, target_side=None, remove_idx=None):
    """
    Takes a solution of size >= n.
    If size > n, removes trees to reach size n.
    Then optimizes.
    """
    # Re-seed random for this process to ensure unique behavior in optimization
    random.seed(int(time.time() * 1000000) + os.getpid() + (remove_idx if remove_idx is not None else 0))
    np.random.seed(int(time.time() * 1000000) + os.getpid() + (remove_idx if remove_idx is not None else 0))
    
    current_trees = [ChristmasTree(t.center_x, t.center_y, t.angle) for t in base_trees]
    
    # Remove trees if needed (Shrink strategy)
    while len(current_trees) > n:
        if remove_idx is not None and remove_idx < len(current_trees):
            # Remove specific tree requested
            current_trees.pop(remove_idx)
            remove_idx = None # Only use once
        else:
            # Fallback: Remove a tree that contributes to the bounds
            # Cache the union computation
            union = unary_union([t.polygon for t in current_trees])
            minx, miny, maxx, maxy = union.bounds
            
            candidates_to_remove = []
            for i, t in enumerate(current_trees):
                tb = t.polygon.bounds
                if (abs(tb[0] - minx) < 1e-3 or abs(tb[1] - miny) < 1e-3 or 
                    abs(tb[2] - maxx) < 1e-3 or abs(tb[3] - maxy) < 1e-3):
                    candidates_to_remove.append(i)
            
            if candidates_to_remove:
                idx = random.choice(candidates_to_remove)
            else:
                idx = random.randint(0, len(current_trees) - 1)
            current_trees.pop(idx)
    # ADAPTIVE OPTIMIZATION based on N
    # Larger N needs more iterations, smaller N can converge faster
    iterations = max(5000, min(15000, int(n * 50)))  # Scale with N
    candidate_trees = optimize_packing(current_trees, {
        'iterations': iterations,
        'step_size': 1.0,         # Large steps to jump out of local minima
        'angle_step': 45.0,       # Large rotation freedom
        'initial_temp': 2.0,      # Very hot start
        'final_temp': 1e-5,       # Cool down thoroughly
        'compression': 0.1        # Strong gravity to close gaps
    }, target_side=target_side)
        
    # Score Candidate
    side_candidate = get_bounds(candidate_trees)
    score_candidate = (side_candidate ** 2) / n
    
    return (score_candidate, candidate_trees)

# BEAM SEARCH PARAMETERS
BEAM_WIDTH = 12       # Keep top 12 candidates
BRANCH_FACTOR = 8     # Generate 8 children per candidate
n_jobs = multiprocessing.cpu_count()
print(f"Running Reverse Beam Search (200 -> 1) (Width={BEAM_WIDTH}, Branch={BRANCH_FACTOR}) on {n_jobs} cores.")

packer_params = {'n_trials': 200, 'step_size': 0.2, 'fine_step': 0.01}
submission_rows = []
improvements = 0

# Initialize candidates with the solution for N=200
if 200 in known_solutions:
    print("Initializing with known solution for N=200.")
    current_candidates = [known_solutions[200]]
else:
    print("ERROR: No solution for N=200 found in baseline. Cannot start reverse search.")
    current_candidates = []

# Metrics Tracking
history_n = []
history_improvement = []
history_total_score = []
current_total_score = 0

# Setup Metrics File
os.makedirs('Data', exist_ok=True)
timestamp_str = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
metrics_file = f'Data/run_metrics_reverse_{timestamp_str}.csv'
with open(metrics_file, 'w') as f:
    f.write('n,score,baseline,improvement,source\n')

# Setup Realtime Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))
plt.close(fig) # Don't show yet
plot_display_id = "metrics_plot_dynamic"
display(fig, display_id=plot_display_id) # Show initial empty plot

# REVERSE LOOP: 200 down to 1
for n in tqdm(range(200, 0, -1), desc="Processing Reverse"):
    
    print(f"\n--- Processing N={n} ---")

    # Get baseline side for pruning/comparison
    baseline_side = None
    if n in known_solutions:
        baseline_side = get_bounds(known_solutions[n])
    
    # 1. Expand candidates in parallel
    tasks = []
    for base_trees in current_candidates:
        # Identify boundary trees for intelligent removal
        # We want to remove trees that are defining the bounds, so the box can shrink.
        minx, miny, maxx, maxy = unary_union([t.polygon for t in base_trees]).bounds
        boundary_indices = []
        for i, t in enumerate(base_trees):
            tb = t.polygon.bounds
            # Check if touching global bounds
            if (abs(tb[0] - minx) < 1e-2 or abs(tb[1] - miny) < 1e-2 or 
                abs(tb[2] - maxx) < 1e-2 or abs(tb[3] - maxy) < 1e-2):
                boundary_indices.append(i)
        
        # If we have enough boundary trees, pick distinct ones. If not, fill with randoms.
        indices_to_try = boundary_indices[:BRANCH_FACTOR]
        while len(indices_to_try) < BRANCH_FACTOR:
            indices_to_try.append(None) # None triggers random selection inside function
            
        for idx in indices_to_try:
            tasks.append((base_trees, n, packer_params, baseline_side, idx))
            
    print(f"  [N={n}] Launching {len(tasks)} parallel tasks (Removal & Optimization)...")
    
    # Run in parallel
    # Run in parallel with error handling
    try:
        results = Parallel(n_jobs=n_jobs)(
            delayed(process_beam_candidate_reverse)(t[0], t[1], t[2], t[3], t[4]) for t in tasks
        )
    except Exception as e:
        print(f"  [N={n}] ERROR in parallel execution: {e}")
        print(f"  [N={n}] Falling back to baseline solution if available...")
        if n in known_solutions:
            results = [((get_bounds(known_solutions[n])**2)/n, known_solutions[n])]
        else:
            print(f"  [N={n}] No fallback available. Skipping...")
            continue
    
    # 2. Sort and select top K (Beam Selection)
    results.sort(key=lambda x: x[0])
    print(f"  [N={n}] Best candidate score: {results[0][0]:.6f}")
    
    # Update current candidates
    unique_candidates = []
    seen_scores = set()
    for res in results:
        s = round(res[0], 6)
        if s not in seen_scores:
            unique_candidates.append(res[1])
            seen_scores.add(s)
        if len(unique_candidates) >= BEAM_WIDTH:
            break
            
    current_candidates = unique_candidates
    
    # The best candidate for this N
    best_score_greedy = results[0][0]
    best_trees_greedy = results[0][1]
    
    # 3. Compare with Baseline
    best_trees_n = best_trees_greedy
    best_score_n = best_score_greedy
    source = "ReverseGreedy"
    baseline_val = 0
    
    if n in known_solutions:
        known_trees = known_solutions[n]
        known_trees = center_packing(known_trees)
        side_known = get_bounds(known_trees)
        score_known = (side_known ** 2) / n
        baseline_val = score_known
        
        print(f"  [N={n}] Baseline score: {score_known:.6f}")

        # Compare (Lower is better)
        # Use a slightly larger epsilon to avoid noise
        if score_known < best_score_greedy - 1e-7:
            best_trees_n = known_trees
            best_score_n = score_known
            source = "Baseline"
            print(f"  [N={n}] Baseline is better. Attempting to optimize baseline...")
            
            # Optimize Baseline (Aggressive pass)
            optimized_known = [ChristmasTree(t.center_x, t.center_y, t.angle) for t in known_trees]
            optimized_known = optimize_packing(optimized_known, {
                'iterations': 20000,      # 20k iterations
                'step_size': 0.8, 
                'angle_step': 20.0, 
                'initial_temp': 1.5,      # Hotter start
                'compression': 0.08
            })
            
            side_opt = get_bounds(optimized_known)
            score_opt = (side_opt ** 2) / n
            
            if score_opt < score_known - 1e-7:
                best_trees_n = optimized_known
                best_score_n = score_opt
                source = "Baseline+Opt"
                improvements += 1
                print(f"  [N={n}] !!! Baseline Optimized! {score_known:.6f} -> {score_opt:.6f}")
            else:
                print(f"  [N={n}] Could not improve baseline.")
                
            # Inject baseline into beam
            current_candidates.append(best_trees_n)
            # Re-sort beam
            temp_candidates = []
            for c in current_candidates:
                s = get_bounds(c)
                temp_candidates.append(((s**2)/n, c))
            temp_candidates.sort(key=lambda x: x[0])
            current_candidates = [x[1] for x in temp_candidates[:BEAM_WIDTH]]
            
        elif best_score_greedy < score_known - 1e-7:
            print(f"  [N={n}] !!! Reverse Search Found Improvement! {score_known:.6f} -> {best_score_greedy:.6f}")
            improvements += 1
        else:
            print(f"  [N={n}] Score matched baseline ({score_known:.6f}). No improvement.")
            
    # 4. Update State & Check Bounds
    all_solutions[n] = best_trees_n
    
    for t in best_trees_n:
        if abs(t.center_x) > 100 or abs(t.center_y) > 100:
            print(f"WARNING: Tree at N={n} outside bounds: ({t.center_x:.2f}, {t.center_y:.2f})")
    
    # 5. Metrics & Plotting
    current_total_score += best_score_n
    imp = max(0, baseline_val - best_score_n) if baseline_val > 0 else 0
    
    print(f"  [N={n}] Finished. Cumulative Score: {current_total_score:.6f} | Total Improvements: {improvements}")

    history_n.append(n)
    history_improvement.append(imp)
    history_total_score.append(current_total_score)
    
    # Save metrics
    with open(metrics_file, 'a') as f:
        f.write(f"{n},{best_score_n:.10f},{baseline_val:.10f},{imp:.10f},{source}\n")
        
    # Realtime Plot (Update every 5 steps)
    if n % 5 == 0 or n == 1:
        # Update axes
        ax1.clear()
        ax2.clear()
        
        # Note: history_n is decreasing [200, 199, ...]
        ax1.plot(history_n, history_improvement, 'g-', label='Improvement')
        ax1.set_title(f'Improvement per N (Total: {improvements})')
        ax1.set_xlabel('N')
        ax1.set_ylabel('Score Reduction')
        ax1.invert_xaxis() # Invert X axis to show 200 -> 1 flow
        ax1.grid(True, alpha=0.3)
        
        ax2.plot(history_n, history_total_score, 'b-', label='Total Score')
        ax2.set_title(f'Cumulative Score: {current_total_score:.4f}')
        ax2.set_xlabel('N')
        ax2.set_ylabel('Total Score')
        ax2.invert_xaxis()
        ax2.grid(True, alpha=0.3)
        
        # Update the display
        display(fig, display_id=plot_display_id, update=True)
    
    # 6. Prepare Submission Rows
    for i, tree in enumerate(best_trees_n):
        submission_rows.append([
            f"{n:03d}_{i}", 
            f"s{tree.center_x:.10f}", 
            f"s{tree.center_y:.10f}", 
            f"s{tree.angle:.10f}"
        ])

print(f"Processing complete. Improvements over baseline/initial: {improvements}")

df_sub = pd.DataFrame(submission_rows, columns=['id', 'x', 'y', 'deg'])
# Sort by ID to ensure 001_... comes first
df_sub.sort_values('id', inplace=True)
df_sub.to_csv('submission.csv', index=False)
print("Submission generated.")
# Out:
# Loading baseline from test.csv...
# Loaded 200 configurations from test.csv
# Running Reverse Beam Search (200 -> 1) (Width=12, Branch=8) on 12 cores.
# Initializing with known solution for N=200.
# Loaded 200 configurations from test.csv
# Running Reverse Beam Search (200 -> 1) (Width=12, Branch=8) on 12 cores.
# Initializing with known solution for N=200.
# Processing Reverse:   0%|          | 0/200 [00:00<?, ?it/s]
# --- Processing N=200 ---
#   [N=200] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=200] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=200] Falling back to baseline solution if available...
#   [N=200] Best candidate score: 0.371064
#   [N=200] Baseline score: 0.371064
#   [N=200] Score matched baseline (0.371064). No improvement.
#   [N=200] Finished. Cumulative Score: 0.371064 | Total Improvements: 0
#   [N=200] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=200] Falling back to baseline solution if available...
#   [N=200] Best candidate score: 0.371064
#   [N=200] Baseline score: 0.371064
#   [N=200] Score matched baseline (0.371064). No improvement.
#   [N=200] Finished. Cumulative Score: 0.371064 | Total Improvements: 0
#
# --- Processing N=199 ---
#   [N=199] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=199 ---
#   [N=199] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=199] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=199] Falling back to baseline solution if available...
#   [N=199] Best candidate score: 0.369846
#   [N=199] Baseline score: 0.369846
#   [N=199] Score matched baseline (0.369846). No improvement.
#   [N=199] Finished. Cumulative Score: 0.740910 | Total Improvements: 0
#
# --- Processing N=198 ---
#   [N=198] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=199] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=199] Falling back to baseline solution if available...
#   [N=199] Best candidate score: 0.369846
#   [N=199] Baseline score: 0.369846
#   [N=199] Score matched baseline (0.369846). No improvement.
#   [N=199] Finished. Cumulative Score: 0.740910 | Total Improvements: 0
#
# --- Processing N=198 ---
#   [N=198] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=198] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=198] Falling back to baseline solution if available...
#   [N=198] Best candidate score: 0.367779
#   [N=198] Baseline score: 0.367779
#   [N=198] Score matched baseline (0.367779). No improvement.
#   [N=198] Finished. Cumulative Score: 1.108689 | Total Improvements: 0
#
# --- Processing N=197 ---
#   [N=197] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=198] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=198] Falling back to baseline solution if available...
#   [N=198] Best candidate score: 0.367779
#   [N=198] Baseline score: 0.367779
#   [N=198] Score matched baseline (0.367779). No improvement.
#   [N=198] Finished. Cumulative Score: 1.108689 | Total Improvements: 0
#
# --- Processing N=197 ---
#   [N=197] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=197] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=197] Falling back to baseline solution if available...
#   [N=197] Best candidate score: 0.369640
#   [N=197] Baseline score: 0.369640
#   [N=197] Score matched baseline (0.369640). No improvement.
#   [N=197] Finished. Cumulative Score: 1.478329 | Total Improvements: 0
#
# --- Processing N=196 ---
#   [N=196] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=197] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=197] Falling back to baseline solution if available...
#   [N=197] Best candidate score: 0.369640
#   [N=197] Baseline score: 0.369640
#   [N=197] Score matched baseline (0.369640). No improvement.
#   [N=197] Finished. Cumulative Score: 1.478329 | Total Improvements: 0
#
# --- Processing N=196 ---
#   [N=196] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=196] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=196] Falling back to baseline solution if available...
#   [N=196] Best candidate score: 0.366871
#   [N=196] Baseline score: 0.366871
#   [N=196] Score matched baseline (0.366871). No improvement.
#   [N=196] Finished. Cumulative Score: 1.845199 | Total Improvements: 0
#
# --- Processing N=195 ---
#   [N=195] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=196] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=196] Falling back to baseline solution if available...
#   [N=196] Best candidate score: 0.366871
#   [N=196] Baseline score: 0.366871
#   [N=196] Score matched baseline (0.366871). No improvement.
#   [N=196] Finished. Cumulative Score: 1.845199 | Total Improvements: 0
#
# --- Processing N=195 ---
#   [N=195] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=195] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=195] Falling back to baseline solution if available...
#   [N=195] Best candidate score: 0.368627
#   [N=195] Baseline score: 0.368627
#   [N=195] Score matched baseline (0.368627). No improvement.
#   [N=195] Finished. Cumulative Score: 2.213827 | Total Improvements: 0
#   [N=195] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=195] Falling back to baseline solution if available...
#   [N=195] Best candidate score: 0.368627
#   [N=195] Baseline score: 0.368627
#   [N=195] Score matched baseline (0.368627). No improvement.
#   [N=195] Finished. Cumulative Score: 2.213827 | Total Improvements: 0
#
# --- Processing N=194 ---
#   [N=194] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=194 ---
#   [N=194] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=194] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=194] Falling back to baseline solution if available...
#   [N=194] Best candidate score: 0.368032
#   [N=194] Baseline score: 0.368032
#   [N=194] Score matched baseline (0.368032). No improvement.
#   [N=194] Finished. Cumulative Score: 2.581859 | Total Improvements: 0
#
# --- Processing N=193 ---
#   [N=193] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=194] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=194] Falling back to baseline solution if available...
#   [N=194] Best candidate score: 0.368032
#   [N=194] Baseline score: 0.368032
#   [N=194] Score matched baseline (0.368032). No improvement.
#   [N=194] Finished. Cumulative Score: 2.581859 | Total Improvements: 0
#
# --- Processing N=193 ---
#   [N=193] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=193] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=193] Falling back to baseline solution if available...
#   [N=193] Best candidate score: 0.368081
#   [N=193] Baseline score: 0.368081
#   [N=193] Score matched baseline (0.368081). No improvement.
#   [N=193] Finished. Cumulative Score: 2.949941 | Total Improvements: 0
#
# --- Processing N=192 ---
#   [N=192] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=193] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=193] Falling back to baseline solution if available...
#   [N=193] Best candidate score: 0.368081
#   [N=193] Baseline score: 0.368081
#   [N=193] Score matched baseline (0.368081). No improvement.
#   [N=193] Finished. Cumulative Score: 2.949941 | Total Improvements: 0
#
# --- Processing N=192 ---
#   [N=192] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=192] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=192] Falling back to baseline solution if available...
#   [N=192] Best candidate score: 0.369021
#   [N=192] Baseline score: 0.369021
#   [N=192] Score matched baseline (0.369021). No improvement.
#   [N=192] Finished. Cumulative Score: 3.318961 | Total Improvements: 0
#
# --- Processing N=191 ---
#   [N=191] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=192] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=192] Falling back to baseline solution if available...
#   [N=192] Best candidate score: 0.369021
#   [N=192] Baseline score: 0.369021
#   [N=192] Score matched baseline (0.369021). No improvement.
#   [N=192] Finished. Cumulative Score: 3.318961 | Total Improvements: 0
#
# --- Processing N=191 ---
#   [N=191] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=191] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=191] Falling back to baseline solution if available...
#   [N=191] Best candidate score: 0.365261
#   [N=191] Baseline score: 0.365261
#   [N=191] Score matched baseline (0.365261). No improvement.
#   [N=191] Finished. Cumulative Score: 3.684223 | Total Improvements: 0
#
# --- Processing N=190 ---
#   [N=190] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=191] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=191] Falling back to baseline solution if available...
#   [N=191] Best candidate score: 0.365261
#   [N=191] Baseline score: 0.365261
#   [N=191] Score matched baseline (0.365261). No improvement.
#   [N=191] Finished. Cumulative Score: 3.684223 | Total Improvements: 0
#
# --- Processing N=190 ---
#   [N=190] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=190] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=190] Falling back to baseline solution if available...
#   [N=190] Best candidate score: 0.367184
#   [N=190] Baseline score: 0.367184
#   [N=190] Score matched baseline (0.367184). No improvement.
#   [N=190] Finished. Cumulative Score: 4.051406 | Total Improvements: 0
#   [N=190] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=190] Falling back to baseline solution if available...
#   [N=190] Best candidate score: 0.367184
#   [N=190] Baseline score: 0.367184
#   [N=190] Score matched baseline (0.367184). No improvement.
#   [N=190] Finished. Cumulative Score: 4.051406 | Total Improvements: 0
#
# --- Processing N=189 ---
#   [N=189] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=189 ---
#   [N=189] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=189] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=189] Falling back to baseline solution if available...
#   [N=189] Best candidate score: 0.369127
#   [N=189] Baseline score: 0.369127
#   [N=189] Score matched baseline (0.369127). No improvement.
#   [N=189] Finished. Cumulative Score: 4.420533 | Total Improvements: 0
#
# --- Processing N=188 ---
#   [N=188] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=189] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=189] Falling back to baseline solution if available...
#   [N=189] Best candidate score: 0.369127
#   [N=189] Baseline score: 0.369127
#   [N=189] Score matched baseline (0.369127). No improvement.
#   [N=189] Finished. Cumulative Score: 4.420533 | Total Improvements: 0
#
# --- Processing N=188 ---
#   [N=188] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=188] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=188] Falling back to baseline solution if available...
#   [N=188] Best candidate score: 0.371090
#   [N=188] Baseline score: 0.371090
#   [N=188] Score matched baseline (0.371090). No improvement.
#   [N=188] Finished. Cumulative Score: 4.791623 | Total Improvements: 0
#
# --- Processing N=187 ---
#   [N=187] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=188] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=188] Falling back to baseline solution if available...
#   [N=188] Best candidate score: 0.371090
#   [N=188] Baseline score: 0.371090
#   [N=188] Score matched baseline (0.371090). No improvement.
#   [N=188] Finished. Cumulative Score: 4.791623 | Total Improvements: 0
#
# --- Processing N=187 ---
#   [N=187] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=187] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=187] Falling back to baseline solution if available...
#   [N=187] Best candidate score: 0.373074
#   [N=187] Baseline score: 0.373074
#   [N=187] Score matched baseline (0.373074). No improvement.
#   [N=187] Finished. Cumulative Score: 5.164697 | Total Improvements: 0
#
# --- Processing N=186 ---
#   [N=186] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=187] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=187] Falling back to baseline solution if available...
#   [N=187] Best candidate score: 0.373074
#   [N=187] Baseline score: 0.373074
#   [N=187] Score matched baseline (0.373074). No improvement.
#   [N=187] Finished. Cumulative Score: 5.164697 | Total Improvements: 0
#
# --- Processing N=186 ---
#   [N=186] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=186] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=186] Falling back to baseline solution if available...
#   [N=186] Best candidate score: 0.373962
#   [N=186] Baseline score: 0.373962
#   [N=186] Score matched baseline (0.373962). No improvement.
#   [N=186] Finished. Cumulative Score: 5.538660 | Total Improvements: 0
#
# --- Processing N=185 ---
#   [N=185] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=186] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=186] Falling back to baseline solution if available...
#   [N=186] Best candidate score: 0.373962
#   [N=186] Baseline score: 0.373962
#   [N=186] Score matched baseline (0.373962). No improvement.
#   [N=186] Finished. Cumulative Score: 5.538660 | Total Improvements: 0
#
# --- Processing N=185 ---
#   [N=185] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=185] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=185] Falling back to baseline solution if available...
#   [N=185] Best candidate score: 0.371467
#   [N=185] Baseline score: 0.371467
#   [N=185] Score matched baseline (0.371467). No improvement.
#   [N=185] Finished. Cumulative Score: 5.910127 | Total Improvements: 0
#   [N=185] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=185] Falling back to baseline solution if available...
#   [N=185] Best candidate score: 0.371467
#   [N=185] Baseline score: 0.371467
#   [N=185] Score matched baseline (0.371467). No improvement.
#   [N=185] Finished. Cumulative Score: 5.910127 | Total Improvements: 0
#
# --- Processing N=184 ---
#   [N=184] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=184 ---
#   [N=184] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=184] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=184] Falling back to baseline solution if available...
#   [N=184] Best candidate score: 0.368552
#   [N=184] Baseline score: 0.368552
#   [N=184] Score matched baseline (0.368552). No improvement.
#   [N=184] Finished. Cumulative Score: 6.278679 | Total Improvements: 0
#
# --- Processing N=183 ---
#   [N=183] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=184] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=184] Falling back to baseline solution if available...
#   [N=184] Best candidate score: 0.368552
#   [N=184] Baseline score: 0.368552
#   [N=184] Score matched baseline (0.368552). No improvement.
#   [N=184] Finished. Cumulative Score: 6.278679 | Total Improvements: 0
#
# --- Processing N=183 ---
#   [N=183] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=183] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=183] Falling back to baseline solution if available...
#   [N=183] Best candidate score: 0.370566
#   [N=183] Baseline score: 0.370566
#   [N=183] Score matched baseline (0.370566). No improvement.
#   [N=183] Finished. Cumulative Score: 6.649245 | Total Improvements: 0
#
# --- Processing N=182 ---
#   [N=182] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=183] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=183] Falling back to baseline solution if available...
#   [N=183] Best candidate score: 0.370566
#   [N=183] Baseline score: 0.370566
#   [N=183] Score matched baseline (0.370566). No improvement.
#   [N=183] Finished. Cumulative Score: 6.649245 | Total Improvements: 0
#
# --- Processing N=182 ---
#   [N=182] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=182] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=182] Falling back to baseline solution if available...
#   [N=182] Best candidate score: 0.367924
#   [N=182] Baseline score: 0.367924
#   [N=182] Score matched baseline (0.367924). No improvement.
#   [N=182] Finished. Cumulative Score: 7.017169 | Total Improvements: 0
#
# --- Processing N=181 ---
#   [N=181] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=182] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=182] Falling back to baseline solution if available...
#   [N=182] Best candidate score: 0.367924
#   [N=182] Baseline score: 0.367924
#   [N=182] Score matched baseline (0.367924). No improvement.
#   [N=182] Finished. Cumulative Score: 7.017169 | Total Improvements: 0
#
# --- Processing N=181 ---
#   [N=181] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=181] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=181] Falling back to baseline solution if available...
#   [N=181] Best candidate score: 0.369957
#   [N=181] Baseline score: 0.369957
#   [N=181] Score matched baseline (0.369957). No improvement.
#   [N=181] Finished. Cumulative Score: 7.387126 | Total Improvements: 0
#
# --- Processing N=180 ---
#   [N=180] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=181] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=181] Falling back to baseline solution if available...
#   [N=181] Best candidate score: 0.369957
#   [N=181] Baseline score: 0.369957
#   [N=181] Score matched baseline (0.369957). No improvement.
#   [N=181] Finished. Cumulative Score: 7.387126 | Total Improvements: 0
#
# --- Processing N=180 ---
#   [N=180] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=180] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=180] Falling back to baseline solution if available...
#   [N=180] Best candidate score: 0.367349
#   [N=180] Baseline score: 0.367349
#   [N=180] Score matched baseline (0.367349). No improvement.
#   [N=180] Finished. Cumulative Score: 7.754475 | Total Improvements: 0
#   [N=180] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=180] Falling back to baseline solution if available...
#   [N=180] Best candidate score: 0.367349
#   [N=180] Baseline score: 0.367349
#   [N=180] Score matched baseline (0.367349). No improvement.
#   [N=180] Finished. Cumulative Score: 7.754475 | Total Improvements: 0
#
# --- Processing N=179 ---
#   [N=179] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=179 ---
#   [N=179] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=179] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=179] Falling back to baseline solution if available...
#   [N=179] Best candidate score: 0.369401
#   [N=179] Baseline score: 0.369401
#   [N=179] Score matched baseline (0.369401). No improvement.
#   [N=179] Finished. Cumulative Score: 8.123876 | Total Improvements: 0
#
# --- Processing N=178 ---
#   [N=178] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=179] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=179] Falling back to baseline solution if available...
#   [N=179] Best candidate score: 0.369401
#   [N=179] Baseline score: 0.369401
#   [N=179] Score matched baseline (0.369401). No improvement.
#   [N=179] Finished. Cumulative Score: 8.123876 | Total Improvements: 0
#
# --- Processing N=178 ---
#   [N=178] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=178] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=178] Falling back to baseline solution if available...
#   [N=178] Best candidate score: 0.371477
#   [N=178] Baseline score: 0.371477
#   [N=178] Score matched baseline (0.371477). No improvement.
#   [N=178] Finished. Cumulative Score: 8.495353 | Total Improvements: 0
#
# --- Processing N=177 ---
#   [N=177] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=178] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=178] Falling back to baseline solution if available...
#   [N=178] Best candidate score: 0.371477
#   [N=178] Baseline score: 0.371477
#   [N=178] Score matched baseline (0.371477). No improvement.
#   [N=178] Finished. Cumulative Score: 8.495353 | Total Improvements: 0
#
# --- Processing N=177 ---
#   [N=177] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=177] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=177] Falling back to baseline solution if available...
#   [N=177] Best candidate score: 0.368320
#   [N=177] Baseline score: 0.368320
#   [N=177] Score matched baseline (0.368320). No improvement.
#   [N=177] Finished. Cumulative Score: 8.863673 | Total Improvements: 0
#
# --- Processing N=176 ---
#   [N=176] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=177] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=177] Falling back to baseline solution if available...
#   [N=177] Best candidate score: 0.368320
#   [N=177] Baseline score: 0.368320
#   [N=177] Score matched baseline (0.368320). No improvement.
#   [N=177] Finished. Cumulative Score: 8.863673 | Total Improvements: 0
#
# --- Processing N=176 ---
#   [N=176] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=176] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=176] Falling back to baseline solution if available...
#   [N=176] Best candidate score: 0.369116
#   [N=176] Baseline score: 0.369116
#   [N=176] Score matched baseline (0.369116). No improvement.
#   [N=176] Finished. Cumulative Score: 9.232788 | Total Improvements: 0
#
# --- Processing N=175 ---
#   [N=175] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=176] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=176] Falling back to baseline solution if available...
#   [N=176] Best candidate score: 0.369116
#   [N=176] Baseline score: 0.369116
#   [N=176] Score matched baseline (0.369116). No improvement.
#   [N=176] Finished. Cumulative Score: 9.232788 | Total Improvements: 0
#
# --- Processing N=175 ---
#   [N=175] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=175] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=175] Falling back to baseline solution if available...
#   [N=175] Best candidate score: 0.371225
#   [N=175] Baseline score: 0.371225
#   [N=175] Score matched baseline (0.371225). No improvement.
#   [N=175] Finished. Cumulative Score: 9.604013 | Total Improvements: 0
#   [N=175] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=175] Falling back to baseline solution if available...
#   [N=175] Best candidate score: 0.371225
#   [N=175] Baseline score: 0.371225
#   [N=175] Score matched baseline (0.371225). No improvement.
#   [N=175] Finished. Cumulative Score: 9.604013 | Total Improvements: 0
#
# --- Processing N=174 ---
#   [N=174] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=174 ---
#   [N=174] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=174] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=174] Falling back to baseline solution if available...
#   [N=174] Best candidate score: 0.368639
#   [N=174] Baseline score: 0.368639
#   [N=174] Score matched baseline (0.368639). No improvement.
#   [N=174] Finished. Cumulative Score: 9.972652 | Total Improvements: 0
#
# --- Processing N=173 ---
#   [N=173] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=174] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=174] Falling back to baseline solution if available...
#   [N=174] Best candidate score: 0.368639
#   [N=174] Baseline score: 0.368639
#   [N=174] Score matched baseline (0.368639). No improvement.
#   [N=174] Finished. Cumulative Score: 9.972652 | Total Improvements: 0
#
# --- Processing N=173 ---
#   [N=173] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=173] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=173] Falling back to baseline solution if available...
#   [N=173] Best candidate score: 0.370614
#   [N=173] Baseline score: 0.370614
#   [N=173] Score matched baseline (0.370614). No improvement.
#   [N=173] Finished. Cumulative Score: 10.343266 | Total Improvements: 0
#
# --- Processing N=172 ---
#   [N=172] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=173] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=173] Falling back to baseline solution if available...
#   [N=173] Best candidate score: 0.370614
#   [N=173] Baseline score: 0.370614
#   [N=173] Score matched baseline (0.370614). No improvement.
#   [N=173] Finished. Cumulative Score: 10.343266 | Total Improvements: 0
#
# --- Processing N=172 ---
#   [N=172] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=172] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=172] Falling back to baseline solution if available...
#   [N=172] Best candidate score: 0.372754
#   [N=172] Baseline score: 0.372754
#   [N=172] Score matched baseline (0.372754). No improvement.
#   [N=172] Finished. Cumulative Score: 10.716020 | Total Improvements: 0
#
# --- Processing N=171 ---
#   [N=171] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=172] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=172] Falling back to baseline solution if available...
#   [N=172] Best candidate score: 0.372754
#   [N=172] Baseline score: 0.372754
#   [N=172] Score matched baseline (0.372754). No improvement.
#   [N=172] Finished. Cumulative Score: 10.716020 | Total Improvements: 0
#
# --- Processing N=171 ---
#   [N=171] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=171] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=171] Falling back to baseline solution if available...
#   [N=171] Best candidate score: 0.374294
#   [N=171] Baseline score: 0.374294
#   [N=171] Score matched baseline (0.374294). No improvement.
#   [N=171] Finished. Cumulative Score: 11.090315 | Total Improvements: 0
#
# --- Processing N=170 ---
#   [N=170] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=171] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=171] Falling back to baseline solution if available...
#   [N=171] Best candidate score: 0.374294
#   [N=171] Baseline score: 0.374294
#   [N=171] Score matched baseline (0.374294). No improvement.
#   [N=171] Finished. Cumulative Score: 11.090315 | Total Improvements: 0
#
# --- Processing N=170 ---
#   [N=170] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=170] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=170] Falling back to baseline solution if available...
#   [N=170] Best candidate score: 0.366964
#   [N=170] Baseline score: 0.366964
#   [N=170] Score matched baseline (0.366964). No improvement.
#   [N=170] Finished. Cumulative Score: 11.457279 | Total Improvements: 0
#   [N=170] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=170] Falling back to baseline solution if available...
#   [N=170] Best candidate score: 0.366964
#   [N=170] Baseline score: 0.366964
#   [N=170] Score matched baseline (0.366964). No improvement.
#   [N=170] Finished. Cumulative Score: 11.457279 | Total Improvements: 0
#
# --- Processing N=169 ---
#   [N=169] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=169 ---
#   [N=169] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=169] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=169] Falling back to baseline solution if available...
#   [N=169] Best candidate score: 0.367435
#   [N=169] Baseline score: 0.367435
#   [N=169] Score matched baseline (0.367435). No improvement.
#   [N=169] Finished. Cumulative Score: 11.824714 | Total Improvements: 0
#
# --- Processing N=168 ---
#   [N=168] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=169] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=169] Falling back to baseline solution if available...
#   [N=169] Best candidate score: 0.367435
#   [N=169] Baseline score: 0.367435
#   [N=169] Score matched baseline (0.367435). No improvement.
#   [N=169] Finished. Cumulative Score: 11.824714 | Total Improvements: 0
#
# --- Processing N=168 ---
#   [N=168] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=168] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=168] Falling back to baseline solution if available...
#   [N=168] Best candidate score: 0.369622
#   [N=168] Baseline score: 0.369622
#   [N=168] Score matched baseline (0.369622). No improvement.
#   [N=168] Finished. Cumulative Score: 12.194336 | Total Improvements: 0
#
# --- Processing N=167 ---
#   [N=167] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=168] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=168] Falling back to baseline solution if available...
#   [N=168] Best candidate score: 0.369622
#   [N=168] Baseline score: 0.369622
#   [N=168] Score matched baseline (0.369622). No improvement.
#   [N=168] Finished. Cumulative Score: 12.194336 | Total Improvements: 0
#
# --- Processing N=167 ---
#   [N=167] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=167] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=167] Falling back to baseline solution if available...
#   [N=167] Best candidate score: 0.369007
#   [N=167] Baseline score: 0.369007
#   [N=167] Score matched baseline (0.369007). No improvement.
#   [N=167] Finished. Cumulative Score: 12.563343 | Total Improvements: 0
#
# --- Processing N=166 ---
#   [N=166] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=167] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=167] Falling back to baseline solution if available...
#   [N=167] Best candidate score: 0.369007
#   [N=167] Baseline score: 0.369007
#   [N=167] Score matched baseline (0.369007). No improvement.
#   [N=167] Finished. Cumulative Score: 12.563343 | Total Improvements: 0
#
# --- Processing N=166 ---
#   [N=166] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=166] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=166] Falling back to baseline solution if available...
#   [N=166] Best candidate score: 0.367188
#   [N=166] Baseline score: 0.367188
#   [N=166] Score matched baseline (0.367188). No improvement.
#   [N=166] Finished. Cumulative Score: 12.930531 | Total Improvements: 0
#
# --- Processing N=165 ---
#   [N=165] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=166] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=166] Falling back to baseline solution if available...
#   [N=166] Best candidate score: 0.367188
#   [N=166] Baseline score: 0.367188
#   [N=166] Score matched baseline (0.367188). No improvement.
#   [N=166] Finished. Cumulative Score: 12.930531 | Total Improvements: 0
#
# --- Processing N=165 ---
#   [N=165] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=165] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=165] Falling back to baseline solution if available...
#   [N=165] Best candidate score: 0.369411
#   [N=165] Baseline score: 0.369411
#   [N=165] Score matched baseline (0.369411). No improvement.
#   [N=165] Finished. Cumulative Score: 13.299942 | Total Improvements: 0
#   [N=165] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=165] Falling back to baseline solution if available...
#   [N=165] Best candidate score: 0.369411
#   [N=165] Baseline score: 0.369411
#   [N=165] Score matched baseline (0.369411). No improvement.
#   [N=165] Finished. Cumulative Score: 13.299942 | Total Improvements: 0
#
# --- Processing N=164 ---
#   [N=164] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=164 ---
#   [N=164] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=164] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=164] Falling back to baseline solution if available...
#   [N=164] Best candidate score: 0.366615
#   [N=164] Baseline score: 0.366615
#   [N=164] Score matched baseline (0.366615). No improvement.
#   [N=164] Finished. Cumulative Score: 13.666557 | Total Improvements: 0
#
# --- Processing N=163 ---
#   [N=163] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=164] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=164] Falling back to baseline solution if available...
#   [N=164] Best candidate score: 0.366615
#   [N=164] Baseline score: 0.366615
#   [N=164] Score matched baseline (0.366615). No improvement.
#   [N=164] Finished. Cumulative Score: 13.666557 | Total Improvements: 0
#
# --- Processing N=163 ---
#   [N=163] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=163] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=163] Falling back to baseline solution if available...
#   [N=163] Best candidate score: 0.368864
#   [N=163] Baseline score: 0.368864
#   [N=163] Score matched baseline (0.368864). No improvement.
#   [N=163] Finished. Cumulative Score: 14.035421 | Total Improvements: 0
#
# --- Processing N=162 ---
#   [N=162] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=163] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=163] Falling back to baseline solution if available...
#   [N=163] Best candidate score: 0.368864
#   [N=163] Baseline score: 0.368864
#   [N=163] Score matched baseline (0.368864). No improvement.
#   [N=163] Finished. Cumulative Score: 14.035421 | Total Improvements: 0
#
# --- Processing N=162 ---
#   [N=162] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=162] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=162] Falling back to baseline solution if available...
#   [N=162] Best candidate score: 0.367476
#   [N=162] Baseline score: 0.367476
#   [N=162] Score matched baseline (0.367476). No improvement.
#   [N=162] Finished. Cumulative Score: 14.402897 | Total Improvements: 0
#
# --- Processing N=161 ---
#   [N=161] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=162] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=162] Falling back to baseline solution if available...
#   [N=162] Best candidate score: 0.367476
#   [N=162] Baseline score: 0.367476
#   [N=162] Score matched baseline (0.367476). No improvement.
#   [N=162] Finished. Cumulative Score: 14.402897 | Total Improvements: 0
#
# --- Processing N=161 ---
#   [N=161] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=161] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=161] Falling back to baseline solution if available...
#   [N=161] Best candidate score: 0.369758
#   [N=161] Baseline score: 0.369758
#   [N=161] Score matched baseline (0.369758). No improvement.
#   [N=161] Finished. Cumulative Score: 14.772655 | Total Improvements: 0
#
# --- Processing N=160 ---
#   [N=160] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=161] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=161] Falling back to baseline solution if available...
#   [N=161] Best candidate score: 0.369758
#   [N=161] Baseline score: 0.369758
#   [N=161] Score matched baseline (0.369758). No improvement.
#   [N=161] Finished. Cumulative Score: 14.772655 | Total Improvements: 0
#
# --- Processing N=160 ---
#   [N=160] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=160] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=160] Falling back to baseline solution if available...
#   [N=160] Best candidate score: 0.368130
#   [N=160] Baseline score: 0.368130
#   [N=160] Score matched baseline (0.368130). No improvement.
#   [N=160] Finished. Cumulative Score: 15.140785 | Total Improvements: 0
#   [N=160] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=160] Falling back to baseline solution if available...
#   [N=160] Best candidate score: 0.368130
#   [N=160] Baseline score: 0.368130
#   [N=160] Score matched baseline (0.368130). No improvement.
#   [N=160] Finished. Cumulative Score: 15.140785 | Total Improvements: 0
#
# --- Processing N=159 ---
#   [N=159] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=159 ---
#   [N=159] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=159] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=159] Falling back to baseline solution if available...
#   [N=159] Best candidate score: 0.370445
#   [N=159] Baseline score: 0.370445
#   [N=159] Score matched baseline (0.370445). No improvement.
#   [N=159] Finished. Cumulative Score: 15.511229 | Total Improvements: 0
#
# --- Processing N=158 ---
#   [N=158] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=159] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=159] Falling back to baseline solution if available...
#   [N=159] Best candidate score: 0.370445
#   [N=159] Baseline score: 0.370445
#   [N=159] Score matched baseline (0.370445). No improvement.
#   [N=159] Finished. Cumulative Score: 15.511229 | Total Improvements: 0
#
# --- Processing N=158 ---
#   [N=158] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=158] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=158] Falling back to baseline solution if available...
#   [N=158] Best candidate score: 0.368926
#   [N=158] Baseline score: 0.368926
#   [N=158] Score matched baseline (0.368926). No improvement.
#   [N=158] Finished. Cumulative Score: 15.880155 | Total Improvements: 0
#
# --- Processing N=157 ---
#   [N=157] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=158] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=158] Falling back to baseline solution if available...
#   [N=158] Best candidate score: 0.368926
#   [N=158] Baseline score: 0.368926
#   [N=158] Score matched baseline (0.368926). No improvement.
#   [N=158] Finished. Cumulative Score: 15.880155 | Total Improvements: 0
#
# --- Processing N=157 ---
#   [N=157] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=157] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=157] Falling back to baseline solution if available...
#   [N=157] Best candidate score: 0.371171
#   [N=157] Baseline score: 0.371171
#   [N=157] Score matched baseline (0.371171). No improvement.
#   [N=157] Finished. Cumulative Score: 16.251327 | Total Improvements: 0
#
# --- Processing N=156 ---
#   [N=156] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=157] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=157] Falling back to baseline solution if available...
#   [N=157] Best candidate score: 0.371171
#   [N=157] Baseline score: 0.371171
#   [N=157] Score matched baseline (0.371171). No improvement.
#   [N=157] Finished. Cumulative Score: 16.251327 | Total Improvements: 0
#
# --- Processing N=156 ---
#   [N=156] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=156] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=156] Falling back to baseline solution if available...
#   [N=156] Best candidate score: 0.363904
#   [N=156] Baseline score: 0.363904
#   [N=156] Score matched baseline (0.363904). No improvement.
#   [N=156] Finished. Cumulative Score: 16.615231 | Total Improvements: 0
#
# --- Processing N=155 ---
#   [N=155] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=156] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=156] Falling back to baseline solution if available...
#   [N=156] Best candidate score: 0.363904
#   [N=156] Baseline score: 0.363904
#   [N=156] Score matched baseline (0.363904). No improvement.
#   [N=156] Finished. Cumulative Score: 16.615231 | Total Improvements: 0
#
# --- Processing N=155 ---
#   [N=155] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=155] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=155] Falling back to baseline solution if available...
#   [N=155] Best candidate score: 0.366252
#   [N=155] Baseline score: 0.366252
#   [N=155] Score matched baseline (0.366252). No improvement.
#   [N=155] Finished. Cumulative Score: 16.981483 | Total Improvements: 0
#   [N=155] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=155] Falling back to baseline solution if available...
#   [N=155] Best candidate score: 0.366252
#   [N=155] Baseline score: 0.366252
#   [N=155] Score matched baseline (0.366252). No improvement.
#   [N=155] Finished. Cumulative Score: 16.981483 | Total Improvements: 0
#
# --- Processing N=154 ---
#   [N=154] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=154 ---
#   [N=154] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=154] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=154] Falling back to baseline solution if available...
#   [N=154] Best candidate score: 0.368630
#   [N=154] Baseline score: 0.368630
#   [N=154] Score matched baseline (0.368630). No improvement.
#   [N=154] Finished. Cumulative Score: 17.350113 | Total Improvements: 0
#
# --- Processing N=153 ---
#   [N=153] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=154] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=154] Falling back to baseline solution if available...
#   [N=154] Best candidate score: 0.368630
#   [N=154] Baseline score: 0.368630
#   [N=154] Score matched baseline (0.368630). No improvement.
#   [N=154] Finished. Cumulative Score: 17.350113 | Total Improvements: 0
#
# --- Processing N=153 ---
#   [N=153] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=153] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=153] Falling back to baseline solution if available...
#   [N=153] Best candidate score: 0.368310
#   [N=153] Baseline score: 0.368310
#   [N=153] Score matched baseline (0.368310). No improvement.
#   [N=153] Finished. Cumulative Score: 17.718423 | Total Improvements: 0
#
# --- Processing N=152 ---
#   [N=152] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=153] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=153] Falling back to baseline solution if available...
#   [N=153] Best candidate score: 0.368310
#   [N=153] Baseline score: 0.368310
#   [N=153] Score matched baseline (0.368310). No improvement.
#   [N=153] Finished. Cumulative Score: 17.718423 | Total Improvements: 0
#
# --- Processing N=152 ---
#   [N=152] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=152] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=152] Falling back to baseline solution if available...
#   [N=152] Best candidate score: 0.370728
#   [N=152] Baseline score: 0.370728
#   [N=152] Score matched baseline (0.370728). No improvement.
#   [N=152] Finished. Cumulative Score: 18.089151 | Total Improvements: 0
#
# --- Processing N=151 ---
#   [N=151] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=152] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=152] Falling back to baseline solution if available...
#   [N=152] Best candidate score: 0.370728
#   [N=152] Baseline score: 0.370728
#   [N=152] Score matched baseline (0.370728). No improvement.
#   [N=152] Finished. Cumulative Score: 18.089151 | Total Improvements: 0
#
# --- Processing N=151 ---
#   [N=151] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=151] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=151] Falling back to baseline solution if available...
#   [N=151] Best candidate score: 0.368427
#   [N=151] Baseline score: 0.368427
#   [N=151] Score matched baseline (0.368427). No improvement.
#   [N=151] Finished. Cumulative Score: 18.457578 | Total Improvements: 0
#
# --- Processing N=150 ---
#   [N=150] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=151] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=151] Falling back to baseline solution if available...
#   [N=151] Best candidate score: 0.368427
#   [N=151] Baseline score: 0.368427
#   [N=151] Score matched baseline (0.368427). No improvement.
#   [N=151] Finished. Cumulative Score: 18.457578 | Total Improvements: 0
#
# --- Processing N=150 ---
#   [N=150] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=150] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=150] Falling back to baseline solution if available...
#   [N=150] Best candidate score: 0.368865
#   [N=150] Baseline score: 0.368865
#   [N=150] Score matched baseline (0.368865). No improvement.
#   [N=150] Finished. Cumulative Score: 18.826442 | Total Improvements: 0
#   [N=150] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=150] Falling back to baseline solution if available...
#   [N=150] Best candidate score: 0.368865
#   [N=150] Baseline score: 0.368865
#   [N=150] Score matched baseline (0.368865). No improvement.
#   [N=150] Finished. Cumulative Score: 18.826442 | Total Improvements: 0
#
# --- Processing N=149 ---
#   [N=149] Launching 8 parallel tasks (Removal & Optimization)...
#
# --- Processing N=149 ---
#   [N=149] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=149] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=149] Falling back to baseline solution if available...
#   [N=149] Best candidate score: 0.371340
#   [N=149] Baseline score: 0.371340
#   [N=149] Score matched baseline (0.371340). No improvement.
#   [N=149] Finished. Cumulative Score: 19.197783 | Total Improvements: 0
#
# --- Processing N=148 ---
#   [N=148] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=149] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=149] Falling back to baseline solution if available...
#   [N=149] Best candidate score: 0.371340
#   [N=149] Baseline score: 0.371340
#   [N=149] Score matched baseline (0.371340). No improvement.
#   [N=149] Finished. Cumulative Score: 19.197783 | Total Improvements: 0
#
# --- Processing N=148 ---
#   [N=148] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=148] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=148] Falling back to baseline solution if available...
#   [N=148] Best candidate score: 0.367375
#   [N=148] Baseline score: 0.367375
#   [N=148] Score matched baseline (0.367375). No improvement.
#   [N=148] Finished. Cumulative Score: 19.565158 | Total Improvements: 0
#
# --- Processing N=147 ---
#   [N=147] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=148] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=148] Falling back to baseline solution if available...
#   [N=148] Best candidate score: 0.367375
#   [N=148] Baseline score: 0.367375
#   [N=148] Score matched baseline (0.367375). No improvement.
#   [N=148] Finished. Cumulative Score: 19.565158 | Total Improvements: 0
#
# --- Processing N=147 ---
#   [N=147] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=147] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=147] Falling back to baseline solution if available...
#   [N=147] Best candidate score: 0.368444
#   [N=147] Baseline score: 0.368444
#   [N=147] Score matched baseline (0.368444). No improvement.
#   [N=147] Finished. Cumulative Score: 19.933602 | Total Improvements: 0
#
# --- Processing N=146 ---
#   [N=146] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=147] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=147] Falling back to baseline solution if available...
#   [N=147] Best candidate score: 0.368444
#   [N=147] Baseline score: 0.368444
#   [N=147] Score matched baseline (0.368444). No improvement.
#   [N=147] Finished. Cumulative Score: 19.933602 | Total Improvements: 0
#
# --- Processing N=146 ---
#   [N=146] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=146] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=146] Falling back to baseline solution if available...
#   [N=146] Best candidate score: 0.370072
#   [N=146] Baseline score: 0.370072
#   [N=146] Score matched baseline (0.370072). No improvement.
#   [N=146] Finished. Cumulative Score: 20.303674 | Total Improvements: 0
#
# --- Processing N=145 ---
#   [N=145] Launching 8 parallel tasks (Removal & Optimization)...
# ...
#   [N=19] Best candidate score: 0.379410
#   [N=19] Baseline score: 0.379410
#   [N=19] Score matched baseline (0.379410). No improvement.
#   [N=19] Finished. Cumulative Score: 67.401481 | Total Improvements: 0
#
# --- Processing N=18 ---
#   [N=18] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=19] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=19] Falling back to baseline solution if available...
#   [N=19] Best candidate score: 0.379410
#   [N=19] Baseline score: 0.379410
#   [N=19] Score matched baseline (0.379410). No improvement.
#   [N=19] Finished. Cumulative Score: 67.401481 | Total Improvements: 0
#
# --- Processing N=18 ---
#   [N=18] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=18] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=18] Falling back to baseline solution if available...
#   [N=18] Best candidate score: 0.371753
#   [N=18] Baseline score: 0.371753
#   [N=18] Score matched baseline (0.371753). No improvement.
#   [N=18] Finished. Cumulative Score: 67.773234 | Total Improvements: 0
#
# --- Processing N=17 ---
#   [N=17] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=18] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=18] Falling back to baseline solution if available...
#   [N=18] Best candidate score: 0.371753
#   [N=18] Baseline score: 0.371753
#   [N=18] Score matched baseline (0.371753). No improvement.
#   [N=18] Finished. Cumulative Score: 67.773234 | Total Improvements: 0
#
# --- Processing N=17 ---
#   [N=17] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=17] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=17] Falling back to baseline solution if available...
#   [N=17] Best candidate score: 0.370996
#   [N=17] Baseline score: 0.370996
#   [N=17] Score matched baseline (0.370996). No improvement.
#   [N=17] Finished. Cumulative Score: 68.144230 | Total Improvements: 0
#
# --- Processing N=16 ---
#   [N=16] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=17] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=17] Falling back to baseline solution if available...
#   [N=17] Best candidate score: 0.370996
#   [N=17] Baseline score: 0.370996
#   [N=17] Score matched baseline (0.370996). No improvement.
#   [N=17] Finished. Cumulative Score: 68.144230 | Total Improvements: 0
#
# --- Processing N=16 ---
#   [N=16] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=16] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=16] Falling back to baseline solution if available...
#   [N=16] Best candidate score: 0.381063
#   [N=16] Baseline score: 0.381063
#   [N=16] Score matched baseline (0.381063). No improvement.
#   [N=16] Finished. Cumulative Score: 68.525293 | Total Improvements: 0
#
# --- Processing N=15 ---
#   [N=15] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=16] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=16] Falling back to baseline solution if available...
#   [N=16] Best candidate score: 0.381063
#   [N=16] Baseline score: 0.381063
#   [N=16] Score matched baseline (0.381063). No improvement.
#   [N=16] Finished. Cumulative Score: 68.525293 | Total Improvements: 0
#
# --- Processing N=15 ---
#   [N=15] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=15] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=15] Falling back to baseline solution if available...
#   [N=15] Best candidate score: 0.380067
#   [N=15] Baseline score: 0.380067
#   [N=15] Score matched baseline (0.380067). No improvement.
#   [N=15] Finished. Cumulative Score: 68.905360 | Total Improvements: 0
#
# --- Processing N=14 ---
#   [N=14] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=15] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=15] Falling back to baseline solution if available...
#   [N=15] Best candidate score: 0.380067
#   [N=15] Baseline score: 0.380067
#   [N=15] Score matched baseline (0.380067). No improvement.
#   [N=15] Finished. Cumulative Score: 68.905360 | Total Improvements: 0
#
# --- Processing N=14 ---
#   [N=14] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=14] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=14] Falling back to baseline solution if available...
#   [N=14] Best candidate score: 0.382486
#   [N=14] Baseline score: 0.382486
#   [N=14] Score matched baseline (0.382486). No improvement.
#   [N=14] Finished. Cumulative Score: 69.287846 | Total Improvements: 0
#
# --- Processing N=13 ---
#   [N=13] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=14] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=14] Falling back to baseline solution if available...
#   [N=14] Best candidate score: 0.382486
#   [N=14] Baseline score: 0.382486
#   [N=14] Score matched baseline (0.382486). No improvement.
#   [N=14] Finished. Cumulative Score: 69.287846 | Total Improvements: 0
#
# --- Processing N=13 ---
#   [N=13] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=13] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=13] Falling back to baseline solution if available...
#   [N=13] Best candidate score: 0.373362
#   [N=13] Baseline score: 0.373362
#   [N=13] Score matched baseline (0.373362). No improvement.
#   [N=13] Finished. Cumulative Score: 69.661208 | Total Improvements: 0
#
# --- Processing N=12 ---
#   [N=12] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=13] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=13] Falling back to baseline solution if available...
#   [N=13] Best candidate score: 0.373362
#   [N=13] Baseline score: 0.373362
#   [N=13] Score matched baseline (0.373362). No improvement.
#   [N=13] Finished. Cumulative Score: 69.661208 | Total Improvements: 0
#
# --- Processing N=12 ---
#   [N=12] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=12] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=12] Falling back to baseline solution if available...
#   [N=12] Best candidate score: 0.375330
#   [N=12] Baseline score: 0.375330
#   [N=12] Score matched baseline (0.375330). No improvement.
#   [N=12] Finished. Cumulative Score: 70.036538 | Total Improvements: 0
#
# --- Processing N=11 ---
#   [N=11] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=12] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=12] Falling back to baseline solution if available...
#   [N=12] Best candidate score: 0.375330
#   [N=12] Baseline score: 0.375330
#   [N=12] Score matched baseline (0.375330). No improvement.
#   [N=12] Finished. Cumulative Score: 70.036538 | Total Improvements: 0
#
# --- Processing N=11 ---
#   [N=11] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=11] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=11] Falling back to baseline solution if available...
#   [N=11] Best candidate score: 0.377119
#   [N=11] Baseline score: 0.377119
#   [N=11] Score matched baseline (0.377119). No improvement.
#   [N=11] Finished. Cumulative Score: 70.413657 | Total Improvements: 0
#
# --- Processing N=10 ---
#   [N=10] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=11] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=11] Falling back to baseline solution if available...
#   [N=11] Best candidate score: 0.377119
#   [N=11] Baseline score: 0.377119
#   [N=11] Score matched baseline (0.377119). No improvement.
#   [N=11] Finished. Cumulative Score: 70.413657 | Total Improvements: 0
#
# --- Processing N=10 ---
#   [N=10] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=10] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=10] Falling back to baseline solution if available...
#   [N=10] Best candidate score: 0.382255
#   [N=10] Baseline score: 0.382255
#   [N=10] Score matched baseline (0.382255). No improvement.
#   [N=10] Finished. Cumulative Score: 70.795912 | Total Improvements: 0
#
# --- Processing N=9 ---
#   [N=9] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=10] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=10] Falling back to baseline solution if available...
#   [N=10] Best candidate score: 0.382255
#   [N=10] Baseline score: 0.382255
#   [N=10] Score matched baseline (0.382255). No improvement.
#   [N=10] Finished. Cumulative Score: 70.795912 | Total Improvements: 0
#
# --- Processing N=9 ---
#   [N=9] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=9] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=9] Falling back to baseline solution if available...
#   [N=9] Best candidate score: 0.387663
#   [N=9] Baseline score: 0.387663
#   [N=9] Score matched baseline (0.387663). No improvement.
#   [N=9] Finished. Cumulative Score: 71.183575 | Total Improvements: 0
#
# --- Processing N=8 ---
#   [N=8] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=9] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=9] Falling back to baseline solution if available...
#   [N=9] Best candidate score: 0.387663
#   [N=9] Baseline score: 0.387663
#   [N=9] Score matched baseline (0.387663). No improvement.
#   [N=9] Finished. Cumulative Score: 71.183575 | Total Improvements: 0
#
# --- Processing N=8 ---
#   [N=8] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=8] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=8] Falling back to baseline solution if available...
#   [N=8] Best candidate score: 0.390438
#   [N=8] Baseline score: 0.390438
#   [N=8] Score matched baseline (0.390438). No improvement.
#   [N=8] Finished. Cumulative Score: 71.574013 | Total Improvements: 0
#
# --- Processing N=7 ---
#   [N=7] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=8] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=8] Falling back to baseline solution if available...
#   [N=8] Best candidate score: 0.390438
#   [N=8] Baseline score: 0.390438
#   [N=8] Score matched baseline (0.390438). No improvement.
#   [N=8] Finished. Cumulative Score: 71.574013 | Total Improvements: 0
#
# --- Processing N=7 ---
#   [N=7] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=7] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=7] Falling back to baseline solution if available...
#   [N=7] Best candidate score: 0.400243
#   [N=7] Baseline score: 0.400243
#   [N=7] Score matched baseline (0.400243). No improvement.
#   [N=7] Finished. Cumulative Score: 71.974255 | Total Improvements: 0
#
# --- Processing N=6 ---
#   [N=6] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=7] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=7] Falling back to baseline solution if available...
#   [N=7] Best candidate score: 0.400243
#   [N=7] Baseline score: 0.400243
#   [N=7] Score matched baseline (0.400243). No improvement.
#   [N=7] Finished. Cumulative Score: 71.974255 | Total Improvements: 0
#
# --- Processing N=6 ---
#   [N=6] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=6] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=6] Falling back to baseline solution if available...
#   [N=6] Best candidate score: 0.400109
#   [N=6] Baseline score: 0.400109
#   [N=6] Score matched baseline (0.400109). No improvement.
#   [N=6] Finished. Cumulative Score: 72.374364 | Total Improvements: 0
#
# --- Processing N=5 ---
#   [N=5] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=6] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=6] Falling back to baseline solution if available...
#   [N=6] Best candidate score: 0.400109
#   [N=6] Baseline score: 0.400109
#   [N=6] Score matched baseline (0.400109). No improvement.
#   [N=6] Finished. Cumulative Score: 72.374364 | Total Improvements: 0
#
# --- Processing N=5 ---
#   [N=5] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=5] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=5] Falling back to baseline solution if available...
#   [N=5] Best candidate score: 0.417134
#   [N=5] Baseline score: 0.417134
#   [N=5] Score matched baseline (0.417134). No improvement.
#   [N=5] Finished. Cumulative Score: 72.791498 | Total Improvements: 0
#
# --- Processing N=4 ---
#   [N=4] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=5] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=5] Falling back to baseline solution if available...
#   [N=5] Best candidate score: 0.417134
#   [N=5] Baseline score: 0.417134
#   [N=5] Score matched baseline (0.417134). No improvement.
#   [N=5] Finished. Cumulative Score: 72.791498 | Total Improvements: 0
#
# --- Processing N=4 ---
#   [N=4] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=4] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=4] Falling back to baseline solution if available...
#   [N=4] Best candidate score: 0.416698
#   [N=4] Baseline score: 0.416698
#   [N=4] Score matched baseline (0.416698). No improvement.
#   [N=4] Finished. Cumulative Score: 73.208196 | Total Improvements: 0
#
# --- Processing N=3 ---
#   [N=3] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=4] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=4] Falling back to baseline solution if available...
#   [N=4] Best candidate score: 0.416698
#   [N=4] Baseline score: 0.416698
#   [N=4] Score matched baseline (0.416698). No improvement.
#   [N=4] Finished. Cumulative Score: 73.208196 | Total Improvements: 0
#
# --- Processing N=3 ---
#   [N=3] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=3] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=3] Falling back to baseline solution if available...
#   [N=3] Best candidate score: 0.434746
#   [N=3] Baseline score: 0.434746
#   [N=3] Score matched baseline (0.434746). No improvement.
#   [N=3] Finished. Cumulative Score: 73.642941 | Total Improvements: 0
#
# --- Processing N=2 ---
#   [N=2] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=3] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=3] Falling back to baseline solution if available...
#   [N=3] Best candidate score: 0.434746
#   [N=3] Baseline score: 0.434746
#   [N=3] Score matched baseline (0.434746). No improvement.
#   [N=3] Finished. Cumulative Score: 73.642941 | Total Improvements: 0
#
# --- Processing N=2 ---
#   [N=2] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=2] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=2] Falling back to baseline solution if available...
#   [N=2] Best candidate score: 0.450792
#   [N=2] Baseline score: 0.450792
#   [N=2] Score matched baseline (0.450792). No improvement.
#   [N=2] Finished. Cumulative Score: 74.093733 | Total Improvements: 0
#
# --- Processing N=1 ---
#   [N=1] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=2] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=2] Falling back to baseline solution if available...
#   [N=2] Best candidate score: 0.450792
#   [N=2] Baseline score: 0.450792
#   [N=2] Score matched baseline (0.450792). No improvement.
#   [N=2] Finished. Cumulative Score: 74.093733 | Total Improvements: 0
#
# --- Processing N=1 ---
#   [N=1] Launching 8 parallel tasks (Removal & Optimization)...
#   [N=1] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=1] Falling back to baseline solution if available...
#   [N=1] Best candidate score: 0.661250
#   [N=1] Baseline score: 0.661250
#   [N=1] Score matched baseline (0.661250). No improvement.
#   [N=1] Finished. Cumulative Score: 74.754983 | Total Improvements: 0
#   [N=1] ERROR in parallel execution: Seed must be between 0 and 2**32 - 1
#   [N=1] Falling back to baseline solution if available...
#   [N=1] Best candidate score: 0.661250
#   [N=1] Baseline score: 0.661250
#   [N=1] Score matched baseline (0.661250). No improvement.
#   [N=1] Finished. Cumulative Score: 74.754983 | Total Improvements: 0
# Processing complete. Improvements over baseline/initial: 0
# Submission generated.
# Processing complete. Improvements over baseline/initial: 0
# Submission generated.

# %%
# Out:
# Generating comparison images...
# Generating Images:   0%|          | 0/200 [00:00<?, ?it/s]
# Images generated in 'images/' directory.

# %% [markdown]
# ## 9. Evaluation Helper
#
# Calculate the local score to estimate leaderboard performance.

# %%
import os
import datetime

# Calculate final score
final_score = 0
for n, trees in all_solutions.items():
    side = get_bounds(trees)
    final_score += (side ** 2) / n

print(f"Final Score: {final_score:.10f}")

# Compare with original
if 'total_test_score' in globals():
    print(f"Original Score: {total_test_score:.10f}")
    if final_score < total_test_score:
        diff = total_test_score - final_score
        print(f"SUCCESS: Score improved by {diff:.10f}!")
        
        # 1. Save copy with detailed name
        os.makedirs('Data', exist_ok=True)
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        detailed_name = f"Data/submission_score{final_score:.2f}_improved{diff:.2f}_{timestamp}.csv"
        df_sub.to_csv(detailed_name, index=False)
        print(f"Saved backup: {detailed_name}")
        
        # 2. Overwrite test.csv
        df_sub.to_csv('test.csv', index=False)
        print("Overwrote test.csv")
        
        # 3. Submit to Kaggle
        message = f"Improved score {final_score:.6f} (was {total_test_score:.6f})"
        print("Submitting to Kaggle...")
        # !kaggle competitions submit -c santa-2025 -f submission.csv -m "{message}"

        # 4. Git Commit and Push
        print("Committing and pushing to Git...")
        # !git add .
        # !git commit -m "{message}"
        # !git push
        
    else:
        print(f"No improvement (Current: {final_score:.10f} >= Original: {total_test_score:.10f}).")
else:
    print("Original score not found. Run the first cell to load test.csv baseline.")
# Out:
# Final Score: 74.7549833598
# Original Score: 74.7550054015
# SUCCESS: Score improved by 0.0000220418!
# Saved backup: Data/submission_score74.75_improved0.00_20251122_194641.csv
# Overwrote test.csv
# Submitting to Kaggle...
# 100%|██████████████████████████████████████| 1.00M/1.00M [00:00<00:00, 2.56MB/s]
# 100%|██████████████████████████████████████| 1.00M/1.00M [00:00<00:00, 2.56MB/s]
# Successfully submitted to Santa 2025 - Christmas Tree Packing ChallengeSuccessfully submitted to Santa 2025 - Christmas Tree Packing ChallengeCommitting and pushing to Git...
# Committing and pushing to Git...
# [main 1705c1e] Improved score 74.754983 (was 74.755005)
# [main 1705c1e] Improved score 74.754983 (was 74.755005)
#  195 files changed, 60084 insertions(+), 39887 deletions(-)
#  create mode 100644 Data/run_metrics_reverse_20251122_185114.csv
#  create mode 100644 Data/submission_score74.75_improved0.00_20251122_194641.csv
#  195 files changed, 60084 insertions(+), 39887 deletions(-)
#  create mode 100644 Data/run_metrics_reverse_20251122_185114.csv
#  create mode 100644 Data/submission_score74.75_improved0.00_20251122_194641.csv
# Enumerating objects: 292, done.
# Counting objects: 100% (292/292), done.
# Delta compression using up to 12 threads
# Enumerating objects: 292, done.97)
# Counting objects: 100% (292/292), done.
# Delta compression using up to 12 threads
# Compressing objects: 100% (197/197), done.
# Compressing objects: 100% (197/197), done.
# Writing objects: 100% (197/197), 87.15 MiB | 34.86 MiB/s, done.
# Total 197 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# Writing objects: 100% (197/197), 87.15 MiB | 34.86 MiB/s, done.
# Total 197 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/lionel509/Santa-2025-Christmas-Tree-Packing-Challenge.git
#    d1326f7..1705c1e  main -> main
# To https://github.com/lionel509/Santa-2025-Christmas-Tree-Packing-Challenge.git
#    d1326f7..1705c1e  main -> main
